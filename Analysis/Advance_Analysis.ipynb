# %% [markdown]
# **Time series analysis of layoff frequency across January to March 2026**

# %%
# Importing Libraries
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.ticker import FuncFormatter


# Loading and Cleaning data
df = pd.read_csv(r"C:\Users\arjun\Desktop\Tech Layoff Analysis\dataset\tech_layoffs_2026_tracker.csv")
df.drop_duplicates(inplace=True,subset=['company','jobs_cut','pct_workforce_cut','sector','country','hq_city','ai_cited','company_revenue_2025_bn','pre_layoff_headcount','stock_change_day_pct','simultaneous_ai_investment_bn'])
df['layoff_date'] = pd.to_datetime(df['layoff_date'])

# %% [markdown]
# **Time series analysis of layoff frequency across January to March 2026**

# %%
df['layoff_month'] = df['layoff_date'].dt.strftime('%b')
df.head()
# Out:
#              company layoff_date  jobs_cut  pct_workforce_cut  \
# 0             Amazon  2026-01-15     16000                2.7
# 1              Block  2026-02-28      4000               40.0
# 2  Meta Reality Labs  2026-01-20      1500               10.0
# 3          Atlassian  2026-03-14      1600               10.0
# 4             Oracle  2026-02-01     30000               15.0
#
#                 sector    country        hq_city  ai_cited  \
# 0     E-Commerce/Cloud        USA        Seattle     False
# 1              Fintech        USA  San Francisco      True
# 2      Social Media/VR        USA     Menlo Park      True
# 3  Enterprise Software  Australia         Sydney      True
# 4  Enterprise Software        USA         Austin      True
#
#                                    reason_stated  company_revenue_2025_bn  \
# 0       Reduce bureaucracy and management layers                    716.9
# 1  AI tools replace roles enabling smaller teams                     22.4
# 2            Pivot from metaverse to AI research                    164.5
# 3             Pivot to AI-first company strategy                      5.1
# 4              AI data centres replace human ops                     52.9
#
#    ...  layoffs_2025           verified_source          month  quarter  \
# 0  ...         14000       CNBC / NetworkWorld   January 2026  Q1 2026
# 1  ...          1000         CNBC / Crunchbase  February 2026  Q1 2026
# 2  ...           500     InformationWeek / NYT   January 2026  Q1 2026
# 3  ...           500  TechRepublic / Metaintro     March 2026  Q1 2026
# 4  ...         10000                   IBTimes  February 2026  Q1 2026
#
#           region layoff_size_category  stock_reaction  \
# 0  North America           Mega (5K+)        Positive
# 1  North America        Large (2K-5K)        Positive
# 2  North America      Medium (500-2K)        Positive
# 3   Asia-Pacific      Medium (500-2K)        Positive
# 4  North America           Mega (5K+)        Positive
#
#    laid_off_vs_headcount_pct      data_as_of layoff_month
# 0                       1.03  March 18, 2026          Jan
# 1                      40.00  March 18, 2026          Feb
# 2                       1.90  March 18, 2026          Jan
# 3                      10.00  March 18, 2026          Mar
# 4                      15.00  March 18, 2026          Feb
#
# [5 rows x 27 columns]

# %%
df_month = df.groupby('layoff_month')[['jobs_cut']].sum().copy()
df_month
# Out:
#               jobs_cut
# layoff_month
# Feb              46588
# Jan              32800
# Mar              20758

# %%
df_month.reset_index(inplace=True)
df_month['month_no'] = pd.to_datetime(df_month['layoff_month'],format='%b').dt.month
df_month
# Out:
#   layoff_month  jobs_cut  month_no
# 0          Feb     46588         2
# 1          Jan     32800         1
# 2          Mar     20758         3

# %%
df_month.sort_values('month_no',inplace=True)
df_month.drop('month_no',axis=1,inplace=True)
df_month.set_index('layoff_month',inplace=True)
df_month
# Out:
#               jobs_cut
# layoff_month
# Jan              32800
# Feb              46588
# Mar              20758

# %%
fig, ax = plt.subplots()
fig.patch.set_facecolor('black')
ax.set_facecolor('black')

df_month.plot(kind='line',marker='o',legend=False, ax=ax,color='#4338CA')
plt.title('First Quater layoffs 2026',color='white')
plt.xlabel('')
ax.yaxis.set_major_formatter(FuncFormatter(lambda x,pos : f'{x/1000:.0f}k'))
ax.tick_params(colors='white',axis='both')
plt.ylabel('Number of Jobs Cut',color='white')

for i in range(0,3):
    plt.text(i+.03,df_month['jobs_cut'].iloc[i],df_month['jobs_cut'].iloc[i],color='white')

for spine in ax.spines.values():
    spine.set_color('white')
sns.despine()
fig.tight_layout()

# %% [markdown]
# **February saw a sharp spike in reported layoffs, largely driven by Oracle, while March returned to a much lower level.**

# %%
df.head()
# Out:
#              company layoff_date  jobs_cut  pct_workforce_cut  \
# 0             Amazon  2026-01-15     16000                2.7
# 1              Block  2026-02-28      4000               40.0
# 2  Meta Reality Labs  2026-01-20      1500               10.0
# 3          Atlassian  2026-03-14      1600               10.0
# 4             Oracle  2026-02-01     30000               15.0
#
#                 sector    country        hq_city  ai_cited  \
# 0     E-Commerce/Cloud        USA        Seattle     False
# 1              Fintech        USA  San Francisco      True
# 2      Social Media/VR        USA     Menlo Park      True
# 3  Enterprise Software  Australia         Sydney      True
# 4  Enterprise Software        USA         Austin      True
#
#                                    reason_stated  company_revenue_2025_bn  \
# 0       Reduce bureaucracy and management layers                    716.9
# 1  AI tools replace roles enabling smaller teams                     22.4
# 2            Pivot from metaverse to AI research                    164.5
# 3             Pivot to AI-first company strategy                      5.1
# 4              AI data centres replace human ops                     52.9
#
#    ...  layoffs_2025           verified_source          month  quarter  \
# 0  ...         14000       CNBC / NetworkWorld   January 2026  Q1 2026
# 1  ...          1000         CNBC / Crunchbase  February 2026  Q1 2026
# 2  ...           500     InformationWeek / NYT   January 2026  Q1 2026
# 3  ...           500  TechRepublic / Metaintro     March 2026  Q1 2026
# 4  ...         10000                   IBTimes  February 2026  Q1 2026
#
#           region layoff_size_category  stock_reaction  \
# 0  North America           Mega (5K+)        Positive
# 1  North America        Large (2K-5K)        Positive
# 2  North America      Medium (500-2K)        Positive
# 3   Asia-Pacific      Medium (500-2K)        Positive
# 4  North America           Mega (5K+)        Positive
#
#    laid_off_vs_headcount_pct      data_as_of layoff_month
# 0                       1.03  March 18, 2026          Jan
# 1                      40.00  March 18, 2026          Feb
# 2                       1.90  March 18, 2026          Jan
# 3                      10.00  March 18, 2026          Mar
# 4                      15.00  March 18, 2026          Feb
#
# [5 rows x 27 columns]

# %% [markdown]
# **Layoff in each Month for all 3 years**

# %%
df_months_years = df.groupby('layoff_month')[['jobs_cut','layoffs_2024','layoffs_2025']].sum()
df_months_years.reset_index(inplace=True)
df_months_years['month_no'] = pd.to_datetime(df_months_years['layoff_month'],format='%b').dt.month
df_months_years.sort_values('month_no',inplace=True)
df_months_years.drop('month_no',inplace=True,axis=1)
df_months_years.set_index('layoff_month')
df_months_years
# Out:
#   layoff_month  jobs_cut  layoffs_2024  layoffs_2025
# 1          Jan     32800         11750         28950
# 0          Feb     46588         11700         23200
# 2          Mar     20758          3000          2500

# %%
df_months_years = df_months_years.rename(columns={'jobs_cut': '2026', 'layoffs_2024':'2024', 'layoffs_2025':'2025'})
fig, ax = plt.subplots()
fig.patch.set_facecolor('black')
ax.set_facecolor('black')
df_months_years.plot(kind='bar', 
                x='layoff_month',
                ax=ax,
                color=['#2563EB', '#DC2626', '#F59E0B'])

ax.yaxis.set_major_formatter(FuncFormatter(lambda x,pos : f'{x/1000:.0f}k'))
ax.tick_params(axis='both',colors='white')
for spine in ax.spines.values():
    spine.set_color('white')
plt.title('Layoffs in each Year by Month',color='white')
plt.ylabel('Jobs Cut',color='white')
plt.xlabel('')
plt.tight_layout()

# %% [markdown]
# **Q1 2026 shows a significantly higher level of reported layoffs compared with Q1 2024 and Q1 2025, with the gap widening sharply in February. However, the February spike is heavily influenced by Oracle’s large layoff event, while March still remains substantially above the previous two years.**

# %%
df
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 0                     Amazon  2026-01-15     16000                2.7
# 1                      Block  2026-02-28      4000               40.0
# 2          Meta Reality Labs  2026-01-20      1500               10.0
# 3                  Atlassian  2026-03-14      1600               10.0
# 4                     Oracle  2026-02-01     30000               15.0
# 5                 Salesforce  2026-01-10      1000                1.4
# 6                   Autodesk  2026-01-25      1000                9.0
# 7                       eBay  2026-01-28       800                5.0
# 8                  Pinterest  2026-02-10       675                4.0
# 9                   Ericsson  2026-01-15      1600               12.0
# 10                      ASML  2026-01-20      1700                3.4
# 11                 ams OSRAM  2026-02-05      2000               12.0
# 12                     Ocado  2026-01-30      1000                7.0
# 13           WiseTech Global  2026-02-20      2000               25.0
# 14                     Cisco  2026-02-15      6000                7.0
# 15                  T-Mobile  2026-02-02       363                0.1
# 16        SK Battery America  2026-03-16       958               37.3
# 17                 Walgreens  2026-03-11      1000                0.5
# 18                Telefonica  2026-01-15      5000                5.0
# 19                       xAI  2026-02-25        50                2.0
# 20        Palo Alto Networks  2026-02-18       500                2.0
# 21                  Livspace  2026-02-10      1000               15.0
# 22       General Motors Tech  2026-01-22      1000                2.0
# 23                   Workday  2026-01-28      2200                8.5
# 24            Ergo Insurance  2026-03-01       200                2.0
# 25              Algoma Steel  2026-03-07      1000               20.0
# 26  Meta Platforms (Planned)  2026-03-13     16000               20.0
#
#                       sector      country          hq_city  ai_cited  \
# 0           E-Commerce/Cloud          USA          Seattle     False
# 1                    Fintech          USA    San Francisco      True
# 2            Social Media/VR          USA       Menlo Park      True
# 3        Enterprise Software    Australia           Sydney      True
# 4        Enterprise Software          USA           Austin      True
# 5                   CRM/SaaS          USA    San Francisco      True
# 6            Design Software          USA    San Francisco     False
# 7                 E-Commerce          USA         San Jose      True
# 8               Social Media          USA    San Francisco      True
# 9         Telecommunications       Sweden        Stockholm     False
# 10            Semiconductors  Netherlands        Veldhoven     False
# 11            Semiconductors      Austria     Premstaetten     False
# 12              Grocery Tech           UK         Hatfield      True
# 13        Logistics Software    Australia           Sydney      True
# 14  Networking/Cybersecurity          USA         San Jose     False
# 15        Telecommunications          USA         Bellevue     False
# 16              EV Batteries          USA      Commerce GA     False
# 17           Retail Pharmacy          USA     Deerfield IL     False
# 18        Telecommunications        Spain           Madrid     False
# 19               AI Research          USA    San Francisco      True
# 20             Cybersecurity          USA      Santa Clara     False
# 21      Interior Design Tech        India        Bangalore      True
# 22           Automotive Tech          USA          Detroit     False
# 23           Enterprise SaaS          USA    Pleasanton CA      True
# 24                 Insurance      Germany       Dusseldorf      True
# 25             Manufacturing       Canada  Sault Ste Marie     False
# 26           Social Media/AI          USA       Menlo Park      True
#
#                                     reason_stated  company_revenue_2025_bn  \
# 0        Reduce bureaucracy and management layers                    716.9
# 1   AI tools replace roles enabling smaller teams                     22.4
# 2             Pivot from metaverse to AI research                    164.5
# 3              Pivot to AI-first company strategy                      5.1
# 4               AI data centres replace human ops                     52.9
# 5          AI-driven efficiency and restructuring                     37.9
# 6            Post-Ansys acquisition restructuring                      5.9
# 7             AI-forward strategy in customer ops                     10.3
# 8       AI-forward content and marketing strategy                      3.6
# 9          Declining 5G demand and cost reduction                     24.3
# 10                           Chip market slowdown                     30.8
# 11         Cost restructuring and portfolio focus                      3.2
# 12          AI automation in warehouse operations                      3.8
# 13               AI replaces QA and testing teams                      3.2
# 14         Restructuring after Splunk acquisition                     56.9
# 15                      Restructuring sales teams                     80.0
# 16                              Slowing EV demand                      8.4
# 17          Store closures and cost restructuring                    140.0
# 18           Cost restructuring with compensation                     44.5
# 19                        Internal reorganization                      0.0
# 20              Post-CyberArk acquisition overlap                      8.0
# 21        AI design tools replace human designers                      0.3
# 22              Rethinking digital transformation                    180.0
# 23       AI investment and office space reduction                      8.5
# 24                   AI automates insurance tasks                      0.0
# 25                          Blast furnace closure                      2.8
# 26                 Offset AI infrastructure costs                    164.5
#
#     ...  layoffs_2025                  verified_source          month  \
# 0   ...         14000              CNBC / NetworkWorld   January 2026
# 1   ...          1000                CNBC / Crunchbase  February 2026
# 2   ...           500            InformationWeek / NYT   January 2026
# 3   ...           500         TechRepublic / Metaintro     March 2026
# 4   ...         10000                          IBTimes  February 2026
# 5   ...          1000         NetworkWorld / Bloomberg   January 2026
# 6   ...          1200                     NetworkWorld   January 2026
# 7   ...          1000                     NetworkWorld   January 2026
# 8   ...           200                     NetworkWorld  February 2026
# 9   ...          5000  InformationWeek / FierceNetwork   January 2026
# 10  ...             0                     NetworkWorld   January 2026
# 11  ...           500                     NetworkWorld  February 2026
# 12  ...             0                     NetworkWorld   January 2026
# 13  ...             0                      Medha Cloud  February 2026
# 14  ...          6000                    Computerworld  February 2026
# 15  ...          5000                    FierceNetwork  February 2026
# 16  ...             0                     Intellizence     March 2026
# 17  ...          2000                     Intellizence     March 2026
# 18  ...          3000                    FierceNetwork   January 2026
# 19  ...             0                       TechCrunch  February 2026
# 20  ...           500                  InformationWeek  February 2026
# 21  ...             0                      Medha Cloud  February 2026
# 22  ...          1500                    Computerworld   January 2026
# 23  ...          1750                    Computerworld   January 2026
# 24  ...             0                     Intellizence     March 2026
# 25  ...             0                     Intellizence     March 2026
# 26  ...             0         CNBC / Reuters / IBTimes     March 2026
#
#     quarter         region layoff_size_category  stock_reaction  \
# 0   Q1 2026  North America           Mega (5K+)        Positive
# 1   Q1 2026  North America        Large (2K-5K)        Positive
# 2   Q1 2026  North America      Medium (500-2K)        Positive
# 3   Q1 2026   Asia-Pacific      Medium (500-2K)        Positive
# 4   Q1 2026  North America           Mega (5K+)        Positive
# 5   Q1 2026  North America      Medium (500-2K)        Positive
# 6   Q1 2026  North America      Medium (500-2K)        Positive
# 7   Q1 2026  North America      Medium (500-2K)        Positive
# 8   Q1 2026  North America      Medium (500-2K)        Positive
# 9   Q1 2026         Europe      Medium (500-2K)        Positive
# 10  Q1 2026         Europe      Medium (500-2K)        Negative
# 11  Q1 2026         Europe      Medium (500-2K)        Positive
# 12  Q1 2026         Europe      Medium (500-2K)        Positive
# 13  Q1 2026   Asia-Pacific      Medium (500-2K)        Positive
# 14  Q1 2026  North America           Mega (5K+)        Negative
# 15  Q1 2026  North America         Small (<500)        Negative
# 16  Q1 2026  North America      Medium (500-2K)        Negative
# 17  Q1 2026  North America      Medium (500-2K)        Negative
# 18  Q1 2026         Europe        Large (2K-5K)        Positive
# 19  Q1 2026  North America         Small (<500)         Neutral
# 20  Q1 2026  North America         Small (<500)        Positive
# 21  Q1 2026   Asia-Pacific      Medium (500-2K)         Neutral
# 22  Q1 2026  North America      Medium (500-2K)        Negative
# 23  Q1 2026  North America        Large (2K-5K)        Positive
# 24  Q1 2026         Europe         Small (<500)         Neutral
# 25  Q1 2026  North America      Medium (500-2K)        Negative
# 26  Q1 2026  North America           Mega (5K+)        Positive
#
#     laid_off_vs_headcount_pct      data_as_of layoff_month
# 0                        1.03  March 18, 2026          Jan
# 1                       40.00  March 18, 2026          Feb
# 2                        1.90  March 18, 2026          Jan
# 3                       10.00  March 18, 2026          Mar
# 4                       15.00  March 18, 2026          Feb
# 5                        1.39  March 18, 2026          Jan
# 6                        9.09  March 18, 2026          Jan
# 7                        7.27  March 18, 2026          Jan
# 8                       18.24  March 18, 2026          Feb
# 9                        1.52  March 18, 2026          Jan
# 10                       4.05  March 18, 2026          Jan
# 11                       9.52  March 18, 2026          Feb
# 12                       7.14  March 18, 2026          Jan
# 13                      25.00  March 18, 2026          Feb
# 14                       7.06  March 18, 2026          Feb
# 15                       0.51  March 18, 2026          Feb
# 16                      37.33  March 18, 2026          Mar
# 17                       0.32  March 18, 2026          Mar
# 18                       5.00  March 18, 2026          Jan
# 19                       2.00  March 18, 2026          Feb
# 20                       3.33  March 18, 2026          Feb
# 21                      14.29  March 18, 2026          Feb
# 22                       0.67  March 18, 2026          Jan
# 23                       8.53  March 18, 2026          Jan
# 24                       2.22  March 18, 2026          Mar
# 25                      20.00  March 18, 2026          Mar
# 26                      20.25  March 18, 2026          Mar
#
# [27 rows x 27 columns]

# %% [markdown]
# **Compare AI-cited vs non-AI-cited layoffs by size, sector and stock reaction**

# %%
df_pivoted_size = (
    df.pivot_table(
        index='layoff_size_category',
        columns='ai_cited',
        values='jobs_cut',
        aggfunc='sum'
    )
    .sort_values(True)
)

fig, ax = plt.subplots(figsize=(10, 6))

# Background
fig.patch.set_facecolor('black')
ax.set_facecolor('black')

# Plot
df_pivoted_size.plot(
    kind='barh',
    ax=ax,
    color=['#3730A3', '#F59E0B'],
    edgecolor='none'
)

# Text / ticks
ax.tick_params(axis='both', colors='white')

for spine in ax.spines.values():
    spine.set_color('white')

ax.set_title(
    'AI-Cited vs Non-AI-Cited Layoffs by Size',
    color='white'
)
ax.set_xlabel('Jobs Cut', color='white')
ax.set_ylabel('')
ax.legend(title='AI-Cited')

# Legend text white
ax.legend(
    title='AI-Cited',
    title_fontsize=10,
    labelcolor='black'
)

plt.tight_layout()
plt.show()

# %% [markdown]
# **AI-cited layoffs were more prominent in higher-size categories, exceeding non-AI layoffs in both Large and Mega layoffs, while non-AI layoffs were higher in Small and Medium categories. However, the Mega AI category is heavily influenced by Oracle’s 30K job reduction.**

# %%
ai_contribution = df.groupby('ai_cited')['jobs_cut'].sum()

fig, ax = plt.subplots(figsize=(6, 6))

fig.patch.set_facecolor('black')
ax.set_facecolor('black')

ai_contribution.plot(
    kind='pie',
    ax=ax,
    autopct='%1.1f%%',
    startangle=90,
    colors=['#3730A3', '#F59E0B'],
    textprops={'color': 'white'}
)

# Percentage text
for text in ax.texts:
    if '%' in text.get_text():
        text.set_color('black')
        text.set_fontweight('bold')

ax.set_ylabel('')
ax.set_title(
    'AI-Cited vs Non-AI-Cited Share of Total Jobs Cut',
    color='white'
)

plt.tight_layout()
plt.show()

# %% [markdown]
# **AI-cited layoffs accounted for 61.9% of total jobs cut, compared with 38.1% for non-AI-cited layoffs, indicating a larger share of job cuts was associated with AI-cited reasons.**

# %%
df.groupby('ai_cited')['stock_change_day_pct'].agg(['mean', 'median'])
# Out:
#               mean  median
# ai_cited
# False    -0.146154    -0.3
# True      1.907143     1.9

# %%
stock_stats = df.groupby('ai_cited')['stock_change_day_pct'].agg(
    mean='mean',
    median='median'
)

stock_stats.index = ['Non-AI Cited', 'AI Cited']

fig, ax = plt.subplots(figsize=(8, 5))

fig.patch.set_facecolor('black')
ax.set_facecolor('black')

stock_stats.plot(
    kind='bar',
    ax=ax,
    color=['#3730A3', '#F59E0B'],
    edgecolor='none'
)

# Zero line
ax.axhline(0, color='white', linewidth=0.8)

# Values on bars
for container in ax.containers:
    for bar in container:
        value = bar.get_height()

        if value >= 0:
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                value + 0.05,
                f'{value:.2f}%',
                ha='center',
                va='bottom',
                color='white'
            )
        else:
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                value - 0.05,
                f'{value:.2f}%',
                ha='center',
                va='top',
                color='white'
            )

# Styling
ax.tick_params(axis='both', colors='white')

for spine in ax.spines.values():
    spine.set_color('white')

ax.set_xlabel('Layoff Type', color='white')
ax.set_ylabel('Stock Change (%)', color='white')
ax.set_title('Mean vs Median Stock Reaction', color='white')
ax.set_xticklabels(['Non-AI Cited', 'AI Cited'], rotation=0)
ax.set_ylim(-0.45, 2.15)

legend = ax.legend(title='Statistic')
legend.get_title().set_color('black')

for text in legend.get_texts():
    text.set_color('black')

plt.tight_layout()
plt.show()

# %% [markdown]
# **AI-cited layoffs were associated with a positive stock reaction, with both mean and median changes around +1.9%. In contrast, non-AI-cited layoffs showed a slight negative reaction, with a mean of -0.15% and median of -0.3%.**

# %%
ai_intensity = (
    df.groupby('sector')['ai_cited']
      .mean()
      .mul(100)
)

layoff_impact = (
    df.groupby('sector')['jobs_cut']
      .sum()
)

ai_investment = (
    df.groupby('sector')['simultaneous_ai_investment_bn']
      .mean()
)


from sklearn.preprocessing import MinMaxScaler

risk = pd.DataFrame({
    'AI_Layoff_Intensity': ai_intensity,
    'Layoff_Impact': layoff_impact,
    'AI_Investment': ai_investment
})

scaler = MinMaxScaler()

risk[['AI_Layoff_Intensity',
      'Layoff_Impact',
      'AI_Investment']] = scaler.fit_transform(
          risk[['AI_Layoff_Intensity',
                'Layoff_Impact',
                'AI_Investment']]
      ) * 100


risk['risk_score'] = (
    risk['AI_Layoff_Intensity'] * 0.4 +
    risk['Layoff_Impact'] * 0.35 +
    risk['AI_Investment'] * 0.25
).round(2)

risk = risk.sort_values('risk_score', ascending=False)

# %%
fig, ax = plt.subplots(figsize=(9, 6))

fig.patch.set_facecolor('black')
ax.set_facecolor('black')

risk['risk_score'].plot(
    kind='barh',
    ax=ax,
    color='#3730A3',
    edgecolor='none'
)

ax.invert_yaxis()

# Values on bars
for i, value in enumerate(risk['risk_score']):
    ax.text(
        value + 0.01,
        i,
        f'{value:.2f}',
        va='center',
        color='white'
    )

# Styling
ax.tick_params(axis='both', colors='white')

for spine in ax.spines.values():
    spine.set_color('white')

ax.set_xlabel('Risk Score', color='white')
ax.set_ylabel('')
ax.set_title(
    'AI-Driven Layoff Vulnerability by Sector',
    color='white'
)

plt.tight_layout()
plt.show()

# %% [markdown]
# **software-centric and digital media sectors face the highest risk of displacement, whereas hardware, cybersecurity, and physical manufacturing industries show strong resilience.**

# %% [markdown]
# **Jobs cut vs AI spend for each company simultaneously**

# %%
df[['company','jobs_cut','simultaneous_ai_investment_bn']].sort_values('jobs_cut')
# Out:
#                      company  jobs_cut  simultaneous_ai_investment_bn
# 19                       xAI        50                            6.0
# 24            Ergo Insurance       200                            0.2
# 15                  T-Mobile       363                            0.0
# 20        Palo Alto Networks       500                            0.5
# 8                  Pinterest       675                            0.4
# 7                       eBay       800                            0.8
# 16        SK Battery America       958                            0.0
# 5                 Salesforce      1000                            5.0
# 17                 Walgreens      1000                            0.0
# 25              Algoma Steel      1000                            0.0
# 21                  Livspace      1000                            0.1
# 22       General Motors Tech      1000                            3.0
# 6                   Autodesk      1000                            0.3
# 12                     Ocado      1000                            0.5
# 2          Meta Reality Labs      1500                          115.0
# 3                  Atlassian      1600                            0.5
# 9                   Ericsson      1600                            0.2
# 10                      ASML      1700                            0.0
# 11                 ams OSRAM      2000                            0.0
# 13           WiseTech Global      2000                            0.3
# 23                   Workday      2200                            1.5
# 1                      Block      4000                            2.0
# 18                Telefonica      5000                            0.0
# 14                     Cisco      6000                            2.0
# 26  Meta Platforms (Planned)     16000                          115.0
# 0                     Amazon     16000                          100.0
# 4                     Oracle     30000                           40.0
