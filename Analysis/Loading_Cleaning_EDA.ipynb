# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.ticker import FuncFormatter

# %%
df = pd.read_csv(r"C:\Users\arjun\Desktop\Tech Layoff Analysis\tech_layoffs_2026_tracker.csv")
df
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 0                     Amazon  2026-01-15     16000                2.7
# 1                      Block  2026-02-28      4000               40.0
# 2          Meta Reality Labs  2026-01-20      1500               10.0
# 3                  Atlassian  2026-03-14      1600               10.0
# 4                     Oracle  2026-02-01     30000               15.0
# 5                 Salesforce  2026-01-10      1000                1.4
# 6                   Autodesk  2026-01-25      1000                9.0
# 7                       eBay  2026-01-28       800                5.0
# 8                  Pinterest  2026-02-10       675                4.0
# 9                   Ericsson  2026-01-15      1600               12.0
# 10                      ASML  2026-01-20      1700                3.4
# 11                 ams OSRAM  2026-02-05      2000               12.0
# 12                     Ocado  2026-01-30      1000                7.0
# 13           WiseTech Global  2026-02-20      2000               25.0
# 14                     Cisco  2026-02-15      6000                7.0
# 15                  T-Mobile  2026-02-02       363                0.1
# 16        SK Battery America  2026-03-16       958               37.3
# 17                 Walgreens  2026-03-11      1000                0.5
# 18                Telefonica  2026-01-15      5000                5.0
# 19                       xAI  2026-02-25        50                2.0
# 20        Palo Alto Networks  2026-02-18       500                2.0
# 21                  Livspace  2026-02-10      1000               15.0
# 22       General Motors Tech  2026-01-22      1000                2.0
# 23                   Workday  2026-01-28      2200                8.5
# 24            Ergo Insurance  2026-03-01       200                2.0
# 25              Algoma Steel  2026-03-07      1000               20.0
# 26  Meta Platforms (Planned)  2026-03-13     16000               20.0
# 27              Algoma Steel  2026-03-23      1000               20.0
#
#                       sector      country          hq_city  ai_cited  \
# 0           E-Commerce/Cloud          USA          Seattle     False
# 1                    Fintech          USA    San Francisco      True
# 2            Social Media/VR          USA       Menlo Park      True
# 3        Enterprise Software    Australia           Sydney      True
# 4        Enterprise Software          USA           Austin      True
# 5                   CRM/SaaS          USA    San Francisco      True
# 6            Design Software          USA    San Francisco     False
# 7                 E-Commerce          USA         San Jose      True
# 8               Social Media          USA    San Francisco      True
# 9         Telecommunications       Sweden        Stockholm     False
# 10            Semiconductors  Netherlands        Veldhoven     False
# 11            Semiconductors      Austria     Premstaetten     False
# 12              Grocery Tech           UK         Hatfield      True
# 13        Logistics Software    Australia           Sydney      True
# 14  Networking/Cybersecurity          USA         San Jose     False
# 15        Telecommunications          USA         Bellevue     False
# 16              EV Batteries          USA      Commerce GA     False
# 17           Retail Pharmacy          USA     Deerfield IL     False
# 18        Telecommunications        Spain           Madrid     False
# 19               AI Research          USA    San Francisco      True
# 20             Cybersecurity          USA      Santa Clara     False
# 21      Interior Design Tech        India        Bangalore      True
# 22           Automotive Tech          USA          Detroit     False
# 23           Enterprise SaaS          USA    Pleasanton CA      True
# 24                 Insurance      Germany       Dusseldorf      True
# 25             Manufacturing       Canada  Sault Ste Marie     False
# 26           Social Media/AI          USA       Menlo Park      True
# 27             Manufacturing       Canada  Sault Ste Marie     False
#
#                                     reason_stated  company_revenue_2025_bn  \
# 0        Reduce bureaucracy and management layers                    716.9
# 1   AI tools replace roles enabling smaller teams                     22.4
# 2             Pivot from metaverse to AI research                    164.5
# 3              Pivot to AI-first company strategy                      5.1
# 4               AI data centres replace human ops                     52.9
# 5          AI-driven efficiency and restructuring                     37.9
# 6            Post-Ansys acquisition restructuring                      5.9
# 7             AI-forward strategy in customer ops                     10.3
# 8       AI-forward content and marketing strategy                      3.6
# 9          Declining 5G demand and cost reduction                     24.3
# 10                           Chip market slowdown                     30.8
# 11         Cost restructuring and portfolio focus                      3.2
# 12          AI automation in warehouse operations                      3.8
# 13               AI replaces QA and testing teams                      3.2
# 14         Restructuring after Splunk acquisition                     56.9
# 15                      Restructuring sales teams                     80.0
# 16                              Slowing EV demand                      8.4
# 17          Store closures and cost restructuring                    140.0
# 18           Cost restructuring with compensation                     44.5
# 19                        Internal reorganization                      0.0
# 20              Post-CyberArk acquisition overlap                      8.0
# 21        AI design tools replace human designers                      0.3
# 22              Rethinking digital transformation                    180.0
# 23       AI investment and office space reduction                      8.5
# 24                   AI automates insurance tasks                      0.0
# 25                          Blast furnace closure                      2.8
# 26                 Offset AI infrastructure costs                    164.5
# 27                Blast furnace closure effective                      2.8
#
#     ...  layoffs_2024  layoffs_2025                  verified_source  \
# 0   ...          4000         14000              CNBC / NetworkWorld
# 1   ...             0          1000                CNBC / Crunchbase
# 2   ...             0           500            InformationWeek / NYT
# 3   ...             0           500         TechRepublic / Metaintro
# 4   ...          6000         10000                          IBTimes
# 5   ...          1000          1000         NetworkWorld / Bloomberg
# 6   ...           500          1200                     NetworkWorld
# 7   ...          1000          1000                     NetworkWorld
# 8   ...          1500           200                     NetworkWorld
# 9   ...          3000          5000  InformationWeek / FierceNetwork
# 10  ...             0             0                     NetworkWorld
# 11  ...             0           500                     NetworkWorld
# 12  ...             0             0                     NetworkWorld
# 13  ...             0             0                      Medha Cloud
# 14  ...          4200          6000                    Computerworld
# 15  ...             0          5000                    FierceNetwork
# 16  ...             0             0                     Intellizence
# 17  ...          3000          2000                     Intellizence
# 18  ...             0          3000                    FierceNetwork
# 19  ...             0             0                       TechCrunch
# 20  ...             0           500                  InformationWeek
# 21  ...             0             0                      Medha Cloud
# 22  ...           500          1500                    Computerworld
# 23  ...          1750          1750                    Computerworld
# 24  ...             0             0                     Intellizence
# 25  ...             0             0                     Intellizence
# 26  ...             0             0         CNBC / Reuters / IBTimes
# 27  ...             0             0                     Intellizence
#
#             month  quarter         region  layoff_size_category  \
# 0    January 2026  Q1 2026  North America            Mega (5K+)
# 1   February 2026  Q1 2026  North America         Large (2K-5K)
# 2    January 2026  Q1 2026  North America       Medium (500-2K)
# 3      March 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 4   February 2026  Q1 2026  North America            Mega (5K+)
# 5    January 2026  Q1 2026  North America       Medium (500-2K)
# 6    January 2026  Q1 2026  North America       Medium (500-2K)
# 7    January 2026  Q1 2026  North America       Medium (500-2K)
# 8   February 2026  Q1 2026  North America       Medium (500-2K)
# 9    January 2026  Q1 2026         Europe       Medium (500-2K)
# 10   January 2026  Q1 2026         Europe       Medium (500-2K)
# 11  February 2026  Q1 2026         Europe       Medium (500-2K)
# 12   January 2026  Q1 2026         Europe       Medium (500-2K)
# 13  February 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 14  February 2026  Q1 2026  North America            Mega (5K+)
# 15  February 2026  Q1 2026  North America          Small (<500)
# 16     March 2026  Q1 2026  North America       Medium (500-2K)
# 17     March 2026  Q1 2026  North America       Medium (500-2K)
# 18   January 2026  Q1 2026         Europe         Large (2K-5K)
# 19  February 2026  Q1 2026  North America          Small (<500)
# 20  February 2026  Q1 2026  North America          Small (<500)
# 21  February 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 22   January 2026  Q1 2026  North America       Medium (500-2K)
# 23   January 2026  Q1 2026  North America         Large (2K-5K)
# 24     March 2026  Q1 2026         Europe          Small (<500)
# 25     March 2026  Q1 2026  North America       Medium (500-2K)
# 26     March 2026  Q1 2026  North America            Mega (5K+)
# 27     March 2026  Q1 2026  North America       Medium (500-2K)
#
#     stock_reaction laid_off_vs_headcount_pct      data_as_of
# 0         Positive                      1.03  March 18, 2026
# 1         Positive                     40.00  March 18, 2026
# 2         Positive                      1.90  March 18, 2026
# 3         Positive                     10.00  March 18, 2026
# 4         Positive                     15.00  March 18, 2026
# 5         Positive                      1.39  March 18, 2026
# 6         Positive                      9.09  March 18, 2026
# 7         Positive                      7.27  March 18, 2026
# 8         Positive                     18.24  March 18, 2026
# 9         Positive                      1.52  March 18, 2026
# 10        Negative                      4.05  March 18, 2026
# 11        Positive                      9.52  March 18, 2026
# 12        Positive                      7.14  March 18, 2026
# 13        Positive                     25.00  March 18, 2026
# 14        Negative                      7.06  March 18, 2026
# 15        Negative                      0.51  March 18, 2026
# 16        Negative                     37.33  March 18, 2026
# 17        Negative                      0.32  March 18, 2026
# 18        Positive                      5.00  March 18, 2026
# 19         Neutral                      2.00  March 18, 2026
# 20        Positive                      3.33  March 18, 2026
# 21         Neutral                     14.29  March 18, 2026
# 22        Negative                      0.67  March 18, 2026
# 23        Positive                      8.53  March 18, 2026
# 24         Neutral                      2.22  March 18, 2026
# 25        Negative                     20.00  March 18, 2026
# 26        Positive                     20.25  March 18, 2026
# 27        Negative                     20.00  March 18, 2026
#
# [28 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['company', 'layoff_date', 'jobs_cut', 'pct_workforce_cut', 'sector',
#        'country', 'hq_city', 'ai_cited', 'reason_stated',
#        'company_revenue_2025_bn', 'pre_layoff_headcount',
#        'stock_change_day_pct', 'simultaneous_ai_investment_bn',
#        'roles_most_affected', 'replacement_roles', 'ceo_quote', 'layoffs_2024',
#        'layoffs_2025', 'verified_source', 'month', 'quarter', 'region',
#        'layoff_size_category', 'stock_reaction', 'laid_off_vs_headcount_pct',
#        'data_as_of'],
#       dtype='str')

# %%
df.describe()
# Out:
#            jobs_cut  pct_workforce_cut  company_revenue_2025_bn  \
# count     28.000000          28.000000                 28.00000
# mean    3612.357143          10.639286                 63.62500
# std     6546.591373          10.433505                139.44986
# min       50.000000           0.100000                  0.00000
# 25%      989.500000           2.525000                  3.50000
# 50%     1000.000000           7.750000                  9.40000
# 75%     2050.000000          15.000000                 53.90000
# max    30000.000000          40.000000                716.90000
#
#        pre_layoff_headcount  stock_change_day_pct  \
# count          2.800000e+01             28.000000
# mean           1.076631e+05              0.832143
# std            2.915339e+05              1.742721
# min            2.500000e+03             -2.100000
# 25%            8.750000e+03             -0.325000
# 50%            1.850000e+04              0.650000
# 75%            8.050000e+04              1.850000
# max            1.550000e+06              5.800000
#
#        simultaneous_ai_investment_bn  layoffs_2024  layoffs_2025  \
# count                      28.000000     28.000000     28.000000
# mean                       14.046429    944.642857   1951.785714
# std                        34.751824   1615.511574   3328.482085
# min                         0.000000      0.000000      0.000000
# 25%                         0.000000      0.000000      0.000000
# 50%                         0.450000      0.000000    500.000000
# 75%                         2.250000   1125.000000   1812.500000
# max                       115.000000   6000.000000  14000.000000
#
#        laid_off_vs_headcount_pct
# count                  28.000000
# mean                   10.452143
# std                    10.719330
# min                     0.320000
# 25%                     1.975000
# 50%                     7.205000
# 75%                    15.810000
# max                    40.000000

# %%
df.shape
print(f'No of Rows : {df.shape[0]}')
print(f'No of Columns : {df.shape[1]}')
# Out:
# No of Rows : 28
# No of Columns : 26

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['company'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# Name: company, dtype: bool

# %%
df.tail()
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 23                   Workday  2026-01-28      2200                8.5
# 24            Ergo Insurance  2026-03-01       200                2.0
# 25              Algoma Steel  2026-03-07      1000               20.0
# 26  Meta Platforms (Planned)  2026-03-13     16000               20.0
# 27              Algoma Steel  2026-03-23      1000               20.0
#
#              sector  country          hq_city  ai_cited  \
# 23  Enterprise SaaS      USA    Pleasanton CA      True
# 24        Insurance  Germany       Dusseldorf      True
# 25    Manufacturing   Canada  Sault Ste Marie     False
# 26  Social Media/AI      USA       Menlo Park      True
# 27    Manufacturing   Canada  Sault Ste Marie     False
#
#                                reason_stated  company_revenue_2025_bn  ...  \
# 23  AI investment and office space reduction                      8.5  ...
# 24              AI automates insurance tasks                      0.0  ...
# 25                     Blast furnace closure                      2.8  ...
# 26            Offset AI infrastructure costs                    164.5  ...
# 27           Blast furnace closure effective                      2.8  ...
#
#     layoffs_2024  layoffs_2025           verified_source         month  \
# 23          1750          1750             Computerworld  January 2026
# 24             0             0              Intellizence    March 2026
# 25             0             0              Intellizence    March 2026
# 26             0             0  CNBC / Reuters / IBTimes    March 2026
# 27             0             0              Intellizence    March 2026
#
#     quarter         region  layoff_size_category  stock_reaction  \
# 23  Q1 2026  North America         Large (2K-5K)        Positive
# 24  Q1 2026         Europe          Small (<500)         Neutral
# 25  Q1 2026  North America       Medium (500-2K)        Negative
# 26  Q1 2026  North America            Mega (5K+)        Positive
# 27  Q1 2026  North America       Medium (500-2K)        Negative
#
#    laid_off_vs_headcount_pct      data_as_of
# 23                      8.53  March 18, 2026
# 24                      2.22  March 18, 2026
# 25                     20.00  March 18, 2026
# 26                     20.25  March 18, 2026
# 27                     20.00  March 18, 2026
#
# [5 rows x 26 columns]

# %%
df.duplicated(subset=['company','jobs_cut','pct_workforce_cut','sector','country','hq_city','ai_cited','company_revenue_2025_bn','pre_layoff_headcount','stock_change_day_pct','simultaneous_ai_investment_bn']).sum()
# Out:
# np.int64(1)

# %% [markdown]
# **-We have a Duplicated Row of the Company Algoma Steel**

# %%
# Cleaning duplicated rows
df.drop_duplicates(inplace=True,subset=['company','jobs_cut','pct_workforce_cut','sector','country','hq_city','ai_cited','company_revenue_2025_bn','pre_layoff_headcount','stock_change_day_pct','simultaneous_ai_investment_bn'])

# %%
df.tail()
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 22       General Motors Tech  2026-01-22      1000                2.0
# 23                   Workday  2026-01-28      2200                8.5
# 24            Ergo Insurance  2026-03-01       200                2.0
# 25              Algoma Steel  2026-03-07      1000               20.0
# 26  Meta Platforms (Planned)  2026-03-13     16000               20.0
#
#              sector  country          hq_city  ai_cited  \
# 22  Automotive Tech      USA          Detroit     False
# 23  Enterprise SaaS      USA    Pleasanton CA      True
# 24        Insurance  Germany       Dusseldorf      True
# 25    Manufacturing   Canada  Sault Ste Marie     False
# 26  Social Media/AI      USA       Menlo Park      True
#
#                                reason_stated  company_revenue_2025_bn  ...  \
# 22         Rethinking digital transformation                    180.0  ...
# 23  AI investment and office space reduction                      8.5  ...
# 24              AI automates insurance tasks                      0.0  ...
# 25                     Blast furnace closure                      2.8  ...
# 26            Offset AI infrastructure costs                    164.5  ...
#
#     layoffs_2024  layoffs_2025           verified_source         month  \
# 22           500          1500             Computerworld  January 2026
# 23          1750          1750             Computerworld  January 2026
# 24             0             0              Intellizence    March 2026
# 25             0             0              Intellizence    March 2026
# 26             0             0  CNBC / Reuters / IBTimes    March 2026
#
#     quarter         region  layoff_size_category  stock_reaction  \
# 22  Q1 2026  North America       Medium (500-2K)        Negative
# 23  Q1 2026  North America         Large (2K-5K)        Positive
# 24  Q1 2026         Europe          Small (<500)         Neutral
# 25  Q1 2026  North America       Medium (500-2K)        Negative
# 26  Q1 2026  North America            Mega (5K+)        Positive
#
#    laid_off_vs_headcount_pct      data_as_of
# 22                      0.67  March 18, 2026
# 23                      8.53  March 18, 2026
# 24                      2.22  March 18, 2026
# 25                     20.00  March 18, 2026
# 26                     20.25  March 18, 2026
#
# [5 rows x 26 columns]

# %%
df.dtypes
# Out:
# company                              str
# layoff_date                          str
# jobs_cut                           int64
# pct_workforce_cut                float64
# sector                               str
# country                              str
# hq_city                              str
# ai_cited                            bool
# reason_stated                        str
# company_revenue_2025_bn          float64
# pre_layoff_headcount               int64
# stock_change_day_pct             float64
# simultaneous_ai_investment_bn    float64
# roles_most_affected                  str
# replacement_roles                    str
# ceo_quote                            str
# layoffs_2024                       int64
# layoffs_2025                       int64
# verified_source                      str
# month                                str
# quarter                              str
# region                               str
# layoff_size_category                 str
# stock_reaction                       str
# laid_off_vs_headcount_pct        float64
# data_as_of                           str
# dtype: object

# %%
# layoff_date has string datatype, which should be date
type(df['layoff_date'][0])
# Out:
# str

# %%
# Converting string to date
df['layoff_date'] = pd.to_datetime(df['layoff_date'])

# %%
type(df['layoff_date'][1])
# Out:
# pandas.Timestamp

# %%
df
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 0                     Amazon  2026-01-15     16000                2.7
# 1                      Block  2026-02-28      4000               40.0
# 2          Meta Reality Labs  2026-01-20      1500               10.0
# 3                  Atlassian  2026-03-14      1600               10.0
# 4                     Oracle  2026-02-01     30000               15.0
# 5                 Salesforce  2026-01-10      1000                1.4
# 6                   Autodesk  2026-01-25      1000                9.0
# 7                       eBay  2026-01-28       800                5.0
# 8                  Pinterest  2026-02-10       675                4.0
# 9                   Ericsson  2026-01-15      1600               12.0
# 10                      ASML  2026-01-20      1700                3.4
# 11                 ams OSRAM  2026-02-05      2000               12.0
# 12                     Ocado  2026-01-30      1000                7.0
# 13           WiseTech Global  2026-02-20      2000               25.0
# 14                     Cisco  2026-02-15      6000                7.0
# 15                  T-Mobile  2026-02-02       363                0.1
# 16        SK Battery America  2026-03-16       958               37.3
# 17                 Walgreens  2026-03-11      1000                0.5
# 18                Telefonica  2026-01-15      5000                5.0
# 19                       xAI  2026-02-25        50                2.0
# 20        Palo Alto Networks  2026-02-18       500                2.0
# 21                  Livspace  2026-02-10      1000               15.0
# 22       General Motors Tech  2026-01-22      1000                2.0
# 23                   Workday  2026-01-28      2200                8.5
# 24            Ergo Insurance  2026-03-01       200                2.0
# 25              Algoma Steel  2026-03-07      1000               20.0
# 26  Meta Platforms (Planned)  2026-03-13     16000               20.0
#
#                       sector      country          hq_city  ai_cited  \
# 0           E-Commerce/Cloud          USA          Seattle     False
# 1                    Fintech          USA    San Francisco      True
# 2            Social Media/VR          USA       Menlo Park      True
# 3        Enterprise Software    Australia           Sydney      True
# 4        Enterprise Software          USA           Austin      True
# 5                   CRM/SaaS          USA    San Francisco      True
# 6            Design Software          USA    San Francisco     False
# 7                 E-Commerce          USA         San Jose      True
# 8               Social Media          USA    San Francisco      True
# 9         Telecommunications       Sweden        Stockholm     False
# 10            Semiconductors  Netherlands        Veldhoven     False
# 11            Semiconductors      Austria     Premstaetten     False
# 12              Grocery Tech           UK         Hatfield      True
# 13        Logistics Software    Australia           Sydney      True
# 14  Networking/Cybersecurity          USA         San Jose     False
# 15        Telecommunications          USA         Bellevue     False
# 16              EV Batteries          USA      Commerce GA     False
# 17           Retail Pharmacy          USA     Deerfield IL     False
# 18        Telecommunications        Spain           Madrid     False
# 19               AI Research          USA    San Francisco      True
# 20             Cybersecurity          USA      Santa Clara     False
# 21      Interior Design Tech        India        Bangalore      True
# 22           Automotive Tech          USA          Detroit     False
# 23           Enterprise SaaS          USA    Pleasanton CA      True
# 24                 Insurance      Germany       Dusseldorf      True
# 25             Manufacturing       Canada  Sault Ste Marie     False
# 26           Social Media/AI          USA       Menlo Park      True
#
#                                     reason_stated  company_revenue_2025_bn  \
# 0        Reduce bureaucracy and management layers                    716.9
# 1   AI tools replace roles enabling smaller teams                     22.4
# 2             Pivot from metaverse to AI research                    164.5
# 3              Pivot to AI-first company strategy                      5.1
# 4               AI data centres replace human ops                     52.9
# 5          AI-driven efficiency and restructuring                     37.9
# 6            Post-Ansys acquisition restructuring                      5.9
# 7             AI-forward strategy in customer ops                     10.3
# 8       AI-forward content and marketing strategy                      3.6
# 9          Declining 5G demand and cost reduction                     24.3
# 10                           Chip market slowdown                     30.8
# 11         Cost restructuring and portfolio focus                      3.2
# 12          AI automation in warehouse operations                      3.8
# 13               AI replaces QA and testing teams                      3.2
# 14         Restructuring after Splunk acquisition                     56.9
# 15                      Restructuring sales teams                     80.0
# 16                              Slowing EV demand                      8.4
# 17          Store closures and cost restructuring                    140.0
# 18           Cost restructuring with compensation                     44.5
# 19                        Internal reorganization                      0.0
# 20              Post-CyberArk acquisition overlap                      8.0
# 21        AI design tools replace human designers                      0.3
# 22              Rethinking digital transformation                    180.0
# 23       AI investment and office space reduction                      8.5
# 24                   AI automates insurance tasks                      0.0
# 25                          Blast furnace closure                      2.8
# 26                 Offset AI infrastructure costs                    164.5
#
#     ...  layoffs_2024  layoffs_2025                  verified_source  \
# 0   ...          4000         14000              CNBC / NetworkWorld
# 1   ...             0          1000                CNBC / Crunchbase
# 2   ...             0           500            InformationWeek / NYT
# 3   ...             0           500         TechRepublic / Metaintro
# 4   ...          6000         10000                          IBTimes
# 5   ...          1000          1000         NetworkWorld / Bloomberg
# 6   ...           500          1200                     NetworkWorld
# 7   ...          1000          1000                     NetworkWorld
# 8   ...          1500           200                     NetworkWorld
# 9   ...          3000          5000  InformationWeek / FierceNetwork
# 10  ...             0             0                     NetworkWorld
# 11  ...             0           500                     NetworkWorld
# 12  ...             0             0                     NetworkWorld
# 13  ...             0             0                      Medha Cloud
# 14  ...          4200          6000                    Computerworld
# 15  ...             0          5000                    FierceNetwork
# 16  ...             0             0                     Intellizence
# 17  ...          3000          2000                     Intellizence
# 18  ...             0          3000                    FierceNetwork
# 19  ...             0             0                       TechCrunch
# 20  ...             0           500                  InformationWeek
# 21  ...             0             0                      Medha Cloud
# 22  ...           500          1500                    Computerworld
# 23  ...          1750          1750                    Computerworld
# 24  ...             0             0                     Intellizence
# 25  ...             0             0                     Intellizence
# 26  ...             0             0         CNBC / Reuters / IBTimes
#
#             month  quarter         region  layoff_size_category  \
# 0    January 2026  Q1 2026  North America            Mega (5K+)
# 1   February 2026  Q1 2026  North America         Large (2K-5K)
# 2    January 2026  Q1 2026  North America       Medium (500-2K)
# 3      March 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 4   February 2026  Q1 2026  North America            Mega (5K+)
# 5    January 2026  Q1 2026  North America       Medium (500-2K)
# 6    January 2026  Q1 2026  North America       Medium (500-2K)
# 7    January 2026  Q1 2026  North America       Medium (500-2K)
# 8   February 2026  Q1 2026  North America       Medium (500-2K)
# 9    January 2026  Q1 2026         Europe       Medium (500-2K)
# 10   January 2026  Q1 2026         Europe       Medium (500-2K)
# 11  February 2026  Q1 2026         Europe       Medium (500-2K)
# 12   January 2026  Q1 2026         Europe       Medium (500-2K)
# 13  February 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 14  February 2026  Q1 2026  North America            Mega (5K+)
# 15  February 2026  Q1 2026  North America          Small (<500)
# 16     March 2026  Q1 2026  North America       Medium (500-2K)
# 17     March 2026  Q1 2026  North America       Medium (500-2K)
# 18   January 2026  Q1 2026         Europe         Large (2K-5K)
# 19  February 2026  Q1 2026  North America          Small (<500)
# 20  February 2026  Q1 2026  North America          Small (<500)
# 21  February 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 22   January 2026  Q1 2026  North America       Medium (500-2K)
# 23   January 2026  Q1 2026  North America         Large (2K-5K)
# 24     March 2026  Q1 2026         Europe          Small (<500)
# 25     March 2026  Q1 2026  North America       Medium (500-2K)
# 26     March 2026  Q1 2026  North America            Mega (5K+)
#
#     stock_reaction laid_off_vs_headcount_pct      data_as_of
# 0         Positive                      1.03  March 18, 2026
# 1         Positive                     40.00  March 18, 2026
# 2         Positive                      1.90  March 18, 2026
# 3         Positive                     10.00  March 18, 2026
# 4         Positive                     15.00  March 18, 2026
# 5         Positive                      1.39  March 18, 2026
# 6         Positive                      9.09  March 18, 2026
# 7         Positive                      7.27  March 18, 2026
# 8         Positive                     18.24  March 18, 2026
# 9         Positive                      1.52  March 18, 2026
# 10        Negative                      4.05  March 18, 2026
# 11        Positive                      9.52  March 18, 2026
# 12        Positive                      7.14  March 18, 2026
# 13        Positive                     25.00  March 18, 2026
# 14        Negative                      7.06  March 18, 2026
# 15        Negative                      0.51  March 18, 2026
# 16        Negative                     37.33  March 18, 2026
# 17        Negative                      0.32  March 18, 2026
# 18        Positive                      5.00  March 18, 2026
# 19         Neutral                      2.00  March 18, 2026
# 20        Positive                      3.33  March 18, 2026
# 21         Neutral                     14.29  March 18, 2026
# 22        Negative                      0.67  March 18, 2026
# 23        Positive                      8.53  March 18, 2026
# 24         Neutral                      2.22  March 18, 2026
# 25        Negative                     20.00  March 18, 2026
# 26        Positive                     20.25  March 18, 2026
#
# [27 rows x 26 columns]

# %% [markdown]
# **Workforce cut based on Sectors**

# %%
# Grouping up data
sector_job_cuts = (
    df.groupby('sector')['jobs_cut']
      .sum()
      .sort_values(ascending=True)
)

fig, ax = plt.subplots(figsize=(10, 6))
fig.patch.set_facecolor("white")
ax.set_facecolor("white")

# Normalize values between 0 and 1
norm = mpl.colors.PowerNorm(
    gamma=0.5,
    vmin=sector_job_cuts.min(),
    vmax=sector_job_cuts.max()
)

# Blue gradient
cmap = mpl.cm.Blues

# Give each bar a color according to its value
colors = cmap(norm(sector_job_cuts.values))

# Plot bars
ax.barh(
    sector_job_cuts.index,
    sector_job_cuts.values,
    height=0.8,
    color=colors
)

# Smaller Y-axis labels
ax.tick_params(axis='y', labelsize=9)


#  applying labels
for i,value in enumerate(sector_job_cuts.values):
    plt.text(value+100,i,value,va='center',size=10)

# Remove grid
ax.grid(False)

ax.set_xlabel("Number of Jobs")
ax.set_title("Workforce Layoffs in Different Sectors")

plt.tight_layout()
plt.show()

# %%
df
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 0                     Amazon  2026-01-15     16000                2.7
# 1                      Block  2026-02-28      4000               40.0
# 2          Meta Reality Labs  2026-01-20      1500               10.0
# 3                  Atlassian  2026-03-14      1600               10.0
# 4                     Oracle  2026-02-01     30000               15.0
# 5                 Salesforce  2026-01-10      1000                1.4
# 6                   Autodesk  2026-01-25      1000                9.0
# 7                       eBay  2026-01-28       800                5.0
# 8                  Pinterest  2026-02-10       675                4.0
# 9                   Ericsson  2026-01-15      1600               12.0
# 10                      ASML  2026-01-20      1700                3.4
# 11                 ams OSRAM  2026-02-05      2000               12.0
# 12                     Ocado  2026-01-30      1000                7.0
# 13           WiseTech Global  2026-02-20      2000               25.0
# 14                     Cisco  2026-02-15      6000                7.0
# 15                  T-Mobile  2026-02-02       363                0.1
# 16        SK Battery America  2026-03-16       958               37.3
# 17                 Walgreens  2026-03-11      1000                0.5
# 18                Telefonica  2026-01-15      5000                5.0
# 19                       xAI  2026-02-25        50                2.0
# 20        Palo Alto Networks  2026-02-18       500                2.0
# 21                  Livspace  2026-02-10      1000               15.0
# 22       General Motors Tech  2026-01-22      1000                2.0
# 23                   Workday  2026-01-28      2200                8.5
# 24            Ergo Insurance  2026-03-01       200                2.0
# 25              Algoma Steel  2026-03-07      1000               20.0
# 26  Meta Platforms (Planned)  2026-03-13     16000               20.0
#
#                       sector      country          hq_city  ai_cited  \
# 0           E-Commerce/Cloud          USA          Seattle     False
# 1                    Fintech          USA    San Francisco      True
# 2            Social Media/VR          USA       Menlo Park      True
# 3        Enterprise Software    Australia           Sydney      True
# 4        Enterprise Software          USA           Austin      True
# 5                   CRM/SaaS          USA    San Francisco      True
# 6            Design Software          USA    San Francisco     False
# 7                 E-Commerce          USA         San Jose      True
# 8               Social Media          USA    San Francisco      True
# 9         Telecommunications       Sweden        Stockholm     False
# 10            Semiconductors  Netherlands        Veldhoven     False
# 11            Semiconductors      Austria     Premstaetten     False
# 12              Grocery Tech           UK         Hatfield      True
# 13        Logistics Software    Australia           Sydney      True
# 14  Networking/Cybersecurity          USA         San Jose     False
# 15        Telecommunications          USA         Bellevue     False
# 16              EV Batteries          USA      Commerce GA     False
# 17           Retail Pharmacy          USA     Deerfield IL     False
# 18        Telecommunications        Spain           Madrid     False
# 19               AI Research          USA    San Francisco      True
# 20             Cybersecurity          USA      Santa Clara     False
# 21      Interior Design Tech        India        Bangalore      True
# 22           Automotive Tech          USA          Detroit     False
# 23           Enterprise SaaS          USA    Pleasanton CA      True
# 24                 Insurance      Germany       Dusseldorf      True
# 25             Manufacturing       Canada  Sault Ste Marie     False
# 26           Social Media/AI          USA       Menlo Park      True
#
#                                     reason_stated  company_revenue_2025_bn  \
# 0        Reduce bureaucracy and management layers                    716.9
# 1   AI tools replace roles enabling smaller teams                     22.4
# 2             Pivot from metaverse to AI research                    164.5
# 3              Pivot to AI-first company strategy                      5.1
# 4               AI data centres replace human ops                     52.9
# 5          AI-driven efficiency and restructuring                     37.9
# 6            Post-Ansys acquisition restructuring                      5.9
# 7             AI-forward strategy in customer ops                     10.3
# 8       AI-forward content and marketing strategy                      3.6
# 9          Declining 5G demand and cost reduction                     24.3
# 10                           Chip market slowdown                     30.8
# 11         Cost restructuring and portfolio focus                      3.2
# 12          AI automation in warehouse operations                      3.8
# 13               AI replaces QA and testing teams                      3.2
# 14         Restructuring after Splunk acquisition                     56.9
# 15                      Restructuring sales teams                     80.0
# 16                              Slowing EV demand                      8.4
# 17          Store closures and cost restructuring                    140.0
# 18           Cost restructuring with compensation                     44.5
# 19                        Internal reorganization                      0.0
# 20              Post-CyberArk acquisition overlap                      8.0
# 21        AI design tools replace human designers                      0.3
# 22              Rethinking digital transformation                    180.0
# 23       AI investment and office space reduction                      8.5
# 24                   AI automates insurance tasks                      0.0
# 25                          Blast furnace closure                      2.8
# 26                 Offset AI infrastructure costs                    164.5
#
#     ...  layoffs_2024  layoffs_2025                  verified_source  \
# 0   ...          4000         14000              CNBC / NetworkWorld
# 1   ...             0          1000                CNBC / Crunchbase
# 2   ...             0           500            InformationWeek / NYT
# 3   ...             0           500         TechRepublic / Metaintro
# 4   ...          6000         10000                          IBTimes
# 5   ...          1000          1000         NetworkWorld / Bloomberg
# 6   ...           500          1200                     NetworkWorld
# 7   ...          1000          1000                     NetworkWorld
# 8   ...          1500           200                     NetworkWorld
# 9   ...          3000          5000  InformationWeek / FierceNetwork
# 10  ...             0             0                     NetworkWorld
# 11  ...             0           500                     NetworkWorld
# 12  ...             0             0                     NetworkWorld
# 13  ...             0             0                      Medha Cloud
# 14  ...          4200          6000                    Computerworld
# 15  ...             0          5000                    FierceNetwork
# 16  ...             0             0                     Intellizence
# 17  ...          3000          2000                     Intellizence
# 18  ...             0          3000                    FierceNetwork
# 19  ...             0             0                       TechCrunch
# 20  ...             0           500                  InformationWeek
# 21  ...             0             0                      Medha Cloud
# 22  ...           500          1500                    Computerworld
# 23  ...          1750          1750                    Computerworld
# 24  ...             0             0                     Intellizence
# 25  ...             0             0                     Intellizence
# 26  ...             0             0         CNBC / Reuters / IBTimes
#
#             month  quarter         region  layoff_size_category  \
# 0    January 2026  Q1 2026  North America            Mega (5K+)
# 1   February 2026  Q1 2026  North America         Large (2K-5K)
# 2    January 2026  Q1 2026  North America       Medium (500-2K)
# 3      March 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 4   February 2026  Q1 2026  North America            Mega (5K+)
# 5    January 2026  Q1 2026  North America       Medium (500-2K)
# 6    January 2026  Q1 2026  North America       Medium (500-2K)
# 7    January 2026  Q1 2026  North America       Medium (500-2K)
# 8   February 2026  Q1 2026  North America       Medium (500-2K)
# 9    January 2026  Q1 2026         Europe       Medium (500-2K)
# 10   January 2026  Q1 2026         Europe       Medium (500-2K)
# 11  February 2026  Q1 2026         Europe       Medium (500-2K)
# 12   January 2026  Q1 2026         Europe       Medium (500-2K)
# 13  February 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 14  February 2026  Q1 2026  North America            Mega (5K+)
# 15  February 2026  Q1 2026  North America          Small (<500)
# 16     March 2026  Q1 2026  North America       Medium (500-2K)
# 17     March 2026  Q1 2026  North America       Medium (500-2K)
# 18   January 2026  Q1 2026         Europe         Large (2K-5K)
# 19  February 2026  Q1 2026  North America          Small (<500)
# 20  February 2026  Q1 2026  North America          Small (<500)
# 21  February 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 22   January 2026  Q1 2026  North America       Medium (500-2K)
# 23   January 2026  Q1 2026  North America         Large (2K-5K)
# 24     March 2026  Q1 2026         Europe          Small (<500)
# 25     March 2026  Q1 2026  North America       Medium (500-2K)
# 26     March 2026  Q1 2026  North America            Mega (5K+)
#
#     stock_reaction laid_off_vs_headcount_pct      data_as_of
# 0         Positive                      1.03  March 18, 2026
# 1         Positive                     40.00  March 18, 2026
# 2         Positive                      1.90  March 18, 2026
# 3         Positive                     10.00  March 18, 2026
# 4         Positive                     15.00  March 18, 2026
# 5         Positive                      1.39  March 18, 2026
# 6         Positive                      9.09  March 18, 2026
# 7         Positive                      7.27  March 18, 2026
# 8         Positive                     18.24  March 18, 2026
# 9         Positive                      1.52  March 18, 2026
# 10        Negative                      4.05  March 18, 2026
# 11        Positive                      9.52  March 18, 2026
# 12        Positive                      7.14  March 18, 2026
# 13        Positive                     25.00  March 18, 2026
# 14        Negative                      7.06  March 18, 2026
# 15        Negative                      0.51  March 18, 2026
# 16        Negative                     37.33  March 18, 2026
# 17        Negative                      0.32  March 18, 2026
# 18        Positive                      5.00  March 18, 2026
# 19         Neutral                      2.00  March 18, 2026
# 20        Positive                      3.33  March 18, 2026
# 21         Neutral                     14.29  March 18, 2026
# 22        Negative                      0.67  March 18, 2026
# 23        Positive                      8.53  March 18, 2026
# 24         Neutral                      2.22  March 18, 2026
# 25        Negative                     20.00  March 18, 2026
# 26        Positive                     20.25  March 18, 2026
#
# [27 rows x 26 columns]

# %%
# Slicing Columns
ai_investment_job_cut = df[['company','simultaneous_ai_investment_bn','jobs_cut']].sort_values('simultaneous_ai_investment_bn')
top5_investors = ai_investment_job_cut.tail(5).index.to_list()


# Plotting Chart
sns.set_theme(style='white')
plt.figure(figsize=(10,5))
sns.scatterplot(alpha=.7,sizes = (50,500),data=ai_investment_job_cut,x='simultaneous_ai_investment_bn',y='jobs_cut',size='jobs_cut',legend=False)

# Plotting labels
for i,index in enumerate(top5_investors):
    plt.text(ai_investment_job_cut.loc[index,'simultaneous_ai_investment_bn']+2,ai_investment_job_cut.loc[index,'jobs_cut'],ai_investment_job_cut.loc[index,'company'],size=9)


# Cleaning Graph
ax = plt.gca()
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, pos: f'{x/1000:.0f}K'))
ax.tick_params(axis='y',which='major', left=True, right=False, length=6, width=1.2, color='black')
ax.tick_params(axis='x',which='major', bottom=True, right=False, length=6, width=1.2, color='black')
sns.despine()
plt.title('AI Investment vs Jobs Cut',size='13')
plt.ylabel('Number of Layoffs',size=9)
plt.xlabel('USD in Billions Invested by Companies',size=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# **- Major tech companies making massive AI investments (over $40 billion) all show significant layoffs of 15,000 or more, though the highest spenders don't necessarily have the most layoffs.**

# %% [markdown]
# **- No clear relationship is observed between simultaneous AI investment and the number of jobs cut.**

# %% [markdown]
# **- Oracle stands out as an outlier, recording the highest number of layoffs (~30K) despite a mid-tier AI investment level (~$40B), indicating aggressive operational restructuring relative to its spending.**

# %%
df
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 0                     Amazon  2026-01-15     16000                2.7
# 1                      Block  2026-02-28      4000               40.0
# 2          Meta Reality Labs  2026-01-20      1500               10.0
# 3                  Atlassian  2026-03-14      1600               10.0
# 4                     Oracle  2026-02-01     30000               15.0
# 5                 Salesforce  2026-01-10      1000                1.4
# 6                   Autodesk  2026-01-25      1000                9.0
# 7                       eBay  2026-01-28       800                5.0
# 8                  Pinterest  2026-02-10       675                4.0
# 9                   Ericsson  2026-01-15      1600               12.0
# 10                      ASML  2026-01-20      1700                3.4
# 11                 ams OSRAM  2026-02-05      2000               12.0
# 12                     Ocado  2026-01-30      1000                7.0
# 13           WiseTech Global  2026-02-20      2000               25.0
# 14                     Cisco  2026-02-15      6000                7.0
# 15                  T-Mobile  2026-02-02       363                0.1
# 16        SK Battery America  2026-03-16       958               37.3
# 17                 Walgreens  2026-03-11      1000                0.5
# 18                Telefonica  2026-01-15      5000                5.0
# 19                       xAI  2026-02-25        50                2.0
# 20        Palo Alto Networks  2026-02-18       500                2.0
# 21                  Livspace  2026-02-10      1000               15.0
# 22       General Motors Tech  2026-01-22      1000                2.0
# 23                   Workday  2026-01-28      2200                8.5
# 24            Ergo Insurance  2026-03-01       200                2.0
# 25              Algoma Steel  2026-03-07      1000               20.0
# 26  Meta Platforms (Planned)  2026-03-13     16000               20.0
#
#                       sector      country          hq_city  ai_cited  \
# 0           E-Commerce/Cloud          USA          Seattle     False
# 1                    Fintech          USA    San Francisco      True
# 2            Social Media/VR          USA       Menlo Park      True
# 3        Enterprise Software    Australia           Sydney      True
# 4        Enterprise Software          USA           Austin      True
# 5                   CRM/SaaS          USA    San Francisco      True
# 6            Design Software          USA    San Francisco     False
# 7                 E-Commerce          USA         San Jose      True
# 8               Social Media          USA    San Francisco      True
# 9         Telecommunications       Sweden        Stockholm     False
# 10            Semiconductors  Netherlands        Veldhoven     False
# 11            Semiconductors      Austria     Premstaetten     False
# 12              Grocery Tech           UK         Hatfield      True
# 13        Logistics Software    Australia           Sydney      True
# 14  Networking/Cybersecurity          USA         San Jose     False
# 15        Telecommunications          USA         Bellevue     False
# 16              EV Batteries          USA      Commerce GA     False
# 17           Retail Pharmacy          USA     Deerfield IL     False
# 18        Telecommunications        Spain           Madrid     False
# 19               AI Research          USA    San Francisco      True
# 20             Cybersecurity          USA      Santa Clara     False
# 21      Interior Design Tech        India        Bangalore      True
# 22           Automotive Tech          USA          Detroit     False
# 23           Enterprise SaaS          USA    Pleasanton CA      True
# 24                 Insurance      Germany       Dusseldorf      True
# 25             Manufacturing       Canada  Sault Ste Marie     False
# 26           Social Media/AI          USA       Menlo Park      True
#
#                                     reason_stated  company_revenue_2025_bn  \
# 0        Reduce bureaucracy and management layers                    716.9
# 1   AI tools replace roles enabling smaller teams                     22.4
# 2             Pivot from metaverse to AI research                    164.5
# 3              Pivot to AI-first company strategy                      5.1
# 4               AI data centres replace human ops                     52.9
# 5          AI-driven efficiency and restructuring                     37.9
# 6            Post-Ansys acquisition restructuring                      5.9
# 7             AI-forward strategy in customer ops                     10.3
# 8       AI-forward content and marketing strategy                      3.6
# 9          Declining 5G demand and cost reduction                     24.3
# 10                           Chip market slowdown                     30.8
# 11         Cost restructuring and portfolio focus                      3.2
# 12          AI automation in warehouse operations                      3.8
# 13               AI replaces QA and testing teams                      3.2
# 14         Restructuring after Splunk acquisition                     56.9
# 15                      Restructuring sales teams                     80.0
# 16                              Slowing EV demand                      8.4
# 17          Store closures and cost restructuring                    140.0
# 18           Cost restructuring with compensation                     44.5
# 19                        Internal reorganization                      0.0
# 20              Post-CyberArk acquisition overlap                      8.0
# 21        AI design tools replace human designers                      0.3
# 22              Rethinking digital transformation                    180.0
# 23       AI investment and office space reduction                      8.5
# 24                   AI automates insurance tasks                      0.0
# 25                          Blast furnace closure                      2.8
# 26                 Offset AI infrastructure costs                    164.5
#
#     ...  layoffs_2024  layoffs_2025                  verified_source  \
# 0   ...          4000         14000              CNBC / NetworkWorld
# 1   ...             0          1000                CNBC / Crunchbase
# 2   ...             0           500            InformationWeek / NYT
# 3   ...             0           500         TechRepublic / Metaintro
# 4   ...          6000         10000                          IBTimes
# 5   ...          1000          1000         NetworkWorld / Bloomberg
# 6   ...           500          1200                     NetworkWorld
# 7   ...          1000          1000                     NetworkWorld
# 8   ...          1500           200                     NetworkWorld
# 9   ...          3000          5000  InformationWeek / FierceNetwork
# 10  ...             0             0                     NetworkWorld
# 11  ...             0           500                     NetworkWorld
# 12  ...             0             0                     NetworkWorld
# 13  ...             0             0                      Medha Cloud
# 14  ...          4200          6000                    Computerworld
# 15  ...             0          5000                    FierceNetwork
# 16  ...             0             0                     Intellizence
# 17  ...          3000          2000                     Intellizence
# 18  ...             0          3000                    FierceNetwork
# 19  ...             0             0                       TechCrunch
# 20  ...             0           500                  InformationWeek
# 21  ...             0             0                      Medha Cloud
# 22  ...           500          1500                    Computerworld
# 23  ...          1750          1750                    Computerworld
# 24  ...             0             0                     Intellizence
# 25  ...             0             0                     Intellizence
# 26  ...             0             0         CNBC / Reuters / IBTimes
#
#             month  quarter         region  layoff_size_category  \
# 0    January 2026  Q1 2026  North America            Mega (5K+)
# 1   February 2026  Q1 2026  North America         Large (2K-5K)
# 2    January 2026  Q1 2026  North America       Medium (500-2K)
# 3      March 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 4   February 2026  Q1 2026  North America            Mega (5K+)
# 5    January 2026  Q1 2026  North America       Medium (500-2K)
# 6    January 2026  Q1 2026  North America       Medium (500-2K)
# 7    January 2026  Q1 2026  North America       Medium (500-2K)
# 8   February 2026  Q1 2026  North America       Medium (500-2K)
# 9    January 2026  Q1 2026         Europe       Medium (500-2K)
# 10   January 2026  Q1 2026         Europe       Medium (500-2K)
# 11  February 2026  Q1 2026         Europe       Medium (500-2K)
# 12   January 2026  Q1 2026         Europe       Medium (500-2K)
# 13  February 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 14  February 2026  Q1 2026  North America            Mega (5K+)
# 15  February 2026  Q1 2026  North America          Small (<500)
# 16     March 2026  Q1 2026  North America       Medium (500-2K)
# 17     March 2026  Q1 2026  North America       Medium (500-2K)
# 18   January 2026  Q1 2026         Europe         Large (2K-5K)
# 19  February 2026  Q1 2026  North America          Small (<500)
# 20  February 2026  Q1 2026  North America          Small (<500)
# 21  February 2026  Q1 2026   Asia-Pacific       Medium (500-2K)
# 22   January 2026  Q1 2026  North America       Medium (500-2K)
# 23   January 2026  Q1 2026  North America         Large (2K-5K)
# 24     March 2026  Q1 2026         Europe          Small (<500)
# 25     March 2026  Q1 2026  North America       Medium (500-2K)
# 26     March 2026  Q1 2026  North America            Mega (5K+)
#
#     stock_reaction laid_off_vs_headcount_pct      data_as_of
# 0         Positive                      1.03  March 18, 2026
# 1         Positive                     40.00  March 18, 2026
# 2         Positive                      1.90  March 18, 2026
# 3         Positive                     10.00  March 18, 2026
# 4         Positive                     15.00  March 18, 2026
# 5         Positive                      1.39  March 18, 2026
# 6         Positive                      9.09  March 18, 2026
# 7         Positive                      7.27  March 18, 2026
# 8         Positive                     18.24  March 18, 2026
# 9         Positive                      1.52  March 18, 2026
# 10        Negative                      4.05  March 18, 2026
# 11        Positive                      9.52  March 18, 2026
# 12        Positive                      7.14  March 18, 2026
# 13        Positive                     25.00  March 18, 2026
# 14        Negative                      7.06  March 18, 2026
# 15        Negative                      0.51  March 18, 2026
# 16        Negative                     37.33  March 18, 2026
# 17        Negative                      0.32  March 18, 2026
# 18        Positive                      5.00  March 18, 2026
# 19         Neutral                      2.00  March 18, 2026
# 20        Positive                      3.33  March 18, 2026
# 21         Neutral                     14.29  March 18, 2026
# 22        Negative                      0.67  March 18, 2026
# 23        Positive                      8.53  March 18, 2026
# 24         Neutral                      2.22  March 18, 2026
# 25        Negative                     20.00  March 18, 2026
# 26        Positive                     20.25  March 18, 2026
#
# [27 rows x 26 columns]

# %% [markdown]
# **Lets Check is there any Correlation between Jobs Cut and Revenue Last Year**

# %%
# Slicing dataframe
df_rev_jc = df[['company','jobs_cut','company_revenue_2025_bn']]



# Plotting
plt.figure(figsize=(8,6))
ax = plt.gca()
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, pos: f'{x/1000:.0f}k'))
sns.scatterplot(data=df_rev_jc, y = 'jobs_cut', x = 'company_revenue_2025_bn' )


comp_list = df_rev_jc.sort_values('jobs_cut',ascending=False).head().company.to_list()
for i in comp_list:
    plt.text(df_rev_jc[df_rev_jc['company'] == i].iloc[0,2]+5,df_rev_jc[df_rev_jc['company'] == i].iloc[0,1]+100,i)



# Formatting
sns.despine()
plt.title('Variation in Layoffs by Revenue Last Year')
plt.ylabel('Number of Jobs')
plt.xlabel('Revenue in USD Billion')
plt.tight_layout()
plt.show()

# %% [markdown]
# **There is no clear or strong correlation between a company's revenue and the number of jobs cut in their layoffs.the data shows that layoff sizes are driven by other company-specific factors rather than being directly proportional to how much revenue a company generates.**

# %% [markdown]
# **How many Jobs are Replaced by AI**

# %%
reasons = df['reason_stated'].to_list()

# %%
mapping = {}

for reason in reasons:
    if "AI" in reason:
        mapping[reason] = "AI"
    else:
        mapping[reason] = reason

mapping
# Out:
# {'Reduce bureaucracy and management layers': 'Reduce bureaucracy and management layers',
#  'AI tools replace roles enabling smaller teams': 'AI',
#  'Pivot from metaverse to AI research': 'AI',
#  'Pivot to AI-first company strategy': 'AI',
#  'AI data centres replace human ops': 'AI',
#  'AI-driven efficiency and restructuring': 'AI',
#  'Post-Ansys acquisition restructuring': 'Post-Ansys acquisition restructuring',
#  'AI-forward strategy in customer ops': 'AI',
#  'AI-forward content and marketing strategy': 'AI',
#  'Declining 5G demand and cost reduction': 'Declining 5G demand and cost reduction',
#  'Chip market slowdown': 'Chip market slowdown',
#  'Cost restructuring and portfolio focus': 'Cost restructuring and portfolio focus',
#  'AI automation in warehouse operations': 'AI',
#  'AI replaces QA and testing teams': 'AI',
#  'Restructuring after Splunk acquisition': 'Restructuring after Splunk acquisition',
#  'Restructuring sales teams': 'Restructuring sales teams',
#  'Slowing EV demand': 'Slowing EV demand',
#  'Store closures and cost restructuring': 'Store closures and cost restructuring',
#  'Cost restructuring with compensation': 'Cost restructuring with compensation',
#  'Internal reorganization': 'Internal reorganization',
#  'Post-CyberArk acquisition overlap': 'Post-CyberArk acquisition overlap',
#  'AI design tools replace human designers': 'AI',
#  'Rethinking digital transformation': 'Rethinking digital transformation',
#  'AI investment and office space reduction': 'AI',
#  'AI automates insurance tasks': 'AI',
#  'Blast furnace closure': 'Blast furnace closure',
#  'Offset AI infrastructure costs': 'AI'}

# %%
df['reason_AI'] = df['reason_stated'].apply(lambda x: mapping[x])

# %%
df_cut_count = df.groupby('reason_AI')[['jobs_cut']].sum()
df_cut_count['total_jobs_cut'] = df.jobs_cut.sum()
df_cut_count['percentage_job_cut_reason'] = (df_cut_count['jobs_cut']/df_cut_count['total_jobs_cut']*100).round(2)
df_cut_count_p = df_cut_count.sort_values('percentage_job_cut_reason')

# %%
plt.figure(figsize=(10, 6))

plt.barh(
    df_cut_count_p.index,
    df_cut_count_p['percentage_job_cut_reason']
)

for i, value in enumerate(df_cut_count_p['percentage_job_cut_reason']):
    plt.text(value + 0.2, i, f'{value:.2f}%', va='center')

plt.xlabel('Percentage of Total Job Cuts')
plt.ylabel('')
plt.title('Job Cuts by Reason')
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# **AI-related reasons account for 61.88% of total job cuts, significantly higher than any individual non-AI reason. The remaining cuts are mainly associated with bureaucracy reduction, restructuring, cost reduction, and market slowdown.**

# %%
df
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 0                     Amazon  2026-01-15     16000                2.7
# 1                      Block  2026-02-28      4000               40.0
# 2          Meta Reality Labs  2026-01-20      1500               10.0
# 3                  Atlassian  2026-03-14      1600               10.0
# 4                     Oracle  2026-02-01     30000               15.0
# 5                 Salesforce  2026-01-10      1000                1.4
# 6                   Autodesk  2026-01-25      1000                9.0
# 7                       eBay  2026-01-28       800                5.0
# 8                  Pinterest  2026-02-10       675                4.0
# 9                   Ericsson  2026-01-15      1600               12.0
# 10                      ASML  2026-01-20      1700                3.4
# 11                 ams OSRAM  2026-02-05      2000               12.0
# 12                     Ocado  2026-01-30      1000                7.0
# 13           WiseTech Global  2026-02-20      2000               25.0
# 14                     Cisco  2026-02-15      6000                7.0
# 15                  T-Mobile  2026-02-02       363                0.1
# 16        SK Battery America  2026-03-16       958               37.3
# 17                 Walgreens  2026-03-11      1000                0.5
# 18                Telefonica  2026-01-15      5000                5.0
# 19                       xAI  2026-02-25        50                2.0
# 20        Palo Alto Networks  2026-02-18       500                2.0
# 21                  Livspace  2026-02-10      1000               15.0
# 22       General Motors Tech  2026-01-22      1000                2.0
# 23                   Workday  2026-01-28      2200                8.5
# 24            Ergo Insurance  2026-03-01       200                2.0
# 25              Algoma Steel  2026-03-07      1000               20.0
# 26  Meta Platforms (Planned)  2026-03-13     16000               20.0
#
#                       sector      country          hq_city  ai_cited  \
# 0           E-Commerce/Cloud          USA          Seattle     False
# 1                    Fintech          USA    San Francisco      True
# 2            Social Media/VR          USA       Menlo Park      True
# 3        Enterprise Software    Australia           Sydney      True
# 4        Enterprise Software          USA           Austin      True
# 5                   CRM/SaaS          USA    San Francisco      True
# 6            Design Software          USA    San Francisco     False
# 7                 E-Commerce          USA         San Jose      True
# 8               Social Media          USA    San Francisco      True
# 9         Telecommunications       Sweden        Stockholm     False
# 10            Semiconductors  Netherlands        Veldhoven     False
# 11            Semiconductors      Austria     Premstaetten     False
# 12              Grocery Tech           UK         Hatfield      True
# 13        Logistics Software    Australia           Sydney      True
# 14  Networking/Cybersecurity          USA         San Jose     False
# 15        Telecommunications          USA         Bellevue     False
# 16              EV Batteries          USA      Commerce GA     False
# 17           Retail Pharmacy          USA     Deerfield IL     False
# 18        Telecommunications        Spain           Madrid     False
# 19               AI Research          USA    San Francisco      True
# 20             Cybersecurity          USA      Santa Clara     False
# 21      Interior Design Tech        India        Bangalore      True
# 22           Automotive Tech          USA          Detroit     False
# 23           Enterprise SaaS          USA    Pleasanton CA      True
# 24                 Insurance      Germany       Dusseldorf      True
# 25             Manufacturing       Canada  Sault Ste Marie     False
# 26           Social Media/AI          USA       Menlo Park      True
#
#                                     reason_stated  company_revenue_2025_bn  \
# 0        Reduce bureaucracy and management layers                    716.9
# 1   AI tools replace roles enabling smaller teams                     22.4
# 2             Pivot from metaverse to AI research                    164.5
# 3              Pivot to AI-first company strategy                      5.1
# 4               AI data centres replace human ops                     52.9
# 5          AI-driven efficiency and restructuring                     37.9
# 6            Post-Ansys acquisition restructuring                      5.9
# 7             AI-forward strategy in customer ops                     10.3
# 8       AI-forward content and marketing strategy                      3.6
# 9          Declining 5G demand and cost reduction                     24.3
# 10                           Chip market slowdown                     30.8
# 11         Cost restructuring and portfolio focus                      3.2
# 12          AI automation in warehouse operations                      3.8
# 13               AI replaces QA and testing teams                      3.2
# 14         Restructuring after Splunk acquisition                     56.9
# 15                      Restructuring sales teams                     80.0
# 16                              Slowing EV demand                      8.4
# 17          Store closures and cost restructuring                    140.0
# 18           Cost restructuring with compensation                     44.5
# 19                        Internal reorganization                      0.0
# 20              Post-CyberArk acquisition overlap                      8.0
# 21        AI design tools replace human designers                      0.3
# 22              Rethinking digital transformation                    180.0
# 23       AI investment and office space reduction                      8.5
# 24                   AI automates insurance tasks                      0.0
# 25                          Blast furnace closure                      2.8
# 26                 Offset AI infrastructure costs                    164.5
#
#     ...  layoffs_2025                  verified_source          month  \
# 0   ...         14000              CNBC / NetworkWorld   January 2026
# 1   ...          1000                CNBC / Crunchbase  February 2026
# 2   ...           500            InformationWeek / NYT   January 2026
# 3   ...           500         TechRepublic / Metaintro     March 2026
# 4   ...         10000                          IBTimes  February 2026
# 5   ...          1000         NetworkWorld / Bloomberg   January 2026
# 6   ...          1200                     NetworkWorld   January 2026
# 7   ...          1000                     NetworkWorld   January 2026
# 8   ...           200                     NetworkWorld  February 2026
# 9   ...          5000  InformationWeek / FierceNetwork   January 2026
# 10  ...             0                     NetworkWorld   January 2026
# 11  ...           500                     NetworkWorld  February 2026
# 12  ...             0                     NetworkWorld   January 2026
# 13  ...             0                      Medha Cloud  February 2026
# 14  ...          6000                    Computerworld  February 2026
# 15  ...          5000                    FierceNetwork  February 2026
# 16  ...             0                     Intellizence     March 2026
# 17  ...          2000                     Intellizence     March 2026
# 18  ...          3000                    FierceNetwork   January 2026
# 19  ...             0                       TechCrunch  February 2026
# 20  ...           500                  InformationWeek  February 2026
# 21  ...             0                      Medha Cloud  February 2026
# 22  ...          1500                    Computerworld   January 2026
# 23  ...          1750                    Computerworld   January 2026
# 24  ...             0                     Intellizence     March 2026
# 25  ...             0                     Intellizence     March 2026
# 26  ...             0         CNBC / Reuters / IBTimes     March 2026
#
#     quarter         region layoff_size_category  stock_reaction  \
# 0   Q1 2026  North America           Mega (5K+)        Positive
# 1   Q1 2026  North America        Large (2K-5K)        Positive
# 2   Q1 2026  North America      Medium (500-2K)        Positive
# 3   Q1 2026   Asia-Pacific      Medium (500-2K)        Positive
# 4   Q1 2026  North America           Mega (5K+)        Positive
# 5   Q1 2026  North America      Medium (500-2K)        Positive
# 6   Q1 2026  North America      Medium (500-2K)        Positive
# 7   Q1 2026  North America      Medium (500-2K)        Positive
# 8   Q1 2026  North America      Medium (500-2K)        Positive
# 9   Q1 2026         Europe      Medium (500-2K)        Positive
# 10  Q1 2026         Europe      Medium (500-2K)        Negative
# 11  Q1 2026         Europe      Medium (500-2K)        Positive
# 12  Q1 2026         Europe      Medium (500-2K)        Positive
# 13  Q1 2026   Asia-Pacific      Medium (500-2K)        Positive
# 14  Q1 2026  North America           Mega (5K+)        Negative
# 15  Q1 2026  North America         Small (<500)        Negative
# 16  Q1 2026  North America      Medium (500-2K)        Negative
# 17  Q1 2026  North America      Medium (500-2K)        Negative
# 18  Q1 2026         Europe        Large (2K-5K)        Positive
# 19  Q1 2026  North America         Small (<500)         Neutral
# 20  Q1 2026  North America         Small (<500)        Positive
# 21  Q1 2026   Asia-Pacific      Medium (500-2K)         Neutral
# 22  Q1 2026  North America      Medium (500-2K)        Negative
# 23  Q1 2026  North America        Large (2K-5K)        Positive
# 24  Q1 2026         Europe         Small (<500)         Neutral
# 25  Q1 2026  North America      Medium (500-2K)        Negative
# 26  Q1 2026  North America           Mega (5K+)        Positive
#
#     laid_off_vs_headcount_pct      data_as_of  \
# 0                        1.03  March 18, 2026
# 1                       40.00  March 18, 2026
# 2                        1.90  March 18, 2026
# 3                       10.00  March 18, 2026
# 4                       15.00  March 18, 2026
# 5                        1.39  March 18, 2026
# 6                        9.09  March 18, 2026
# 7                        7.27  March 18, 2026
# 8                       18.24  March 18, 2026
# 9                        1.52  March 18, 2026
# 10                       4.05  March 18, 2026
# 11                       9.52  March 18, 2026
# 12                       7.14  March 18, 2026
# 13                      25.00  March 18, 2026
# 14                       7.06  March 18, 2026
# 15                       0.51  March 18, 2026
# 16                      37.33  March 18, 2026
# 17                       0.32  March 18, 2026
# 18                       5.00  March 18, 2026
# 19                       2.00  March 18, 2026
# 20                       3.33  March 18, 2026
# 21                      14.29  March 18, 2026
# 22                       0.67  March 18, 2026
# 23                       8.53  March 18, 2026
# 24                       2.22  March 18, 2026
# 25                      20.00  March 18, 2026
# 26                      20.25  March 18, 2026
#
#                                    reason_AI
# 0   Reduce bureaucracy and management layers
# 1                                         AI
# 2                                         AI
# 3                                         AI
# 4                                         AI
# 5                                         AI
# 6       Post-Ansys acquisition restructuring
# 7                                         AI
# 8                                         AI
# 9     Declining 5G demand and cost reduction
# 10                      Chip market slowdown
# 11    Cost restructuring and portfolio focus
# 12                                        AI
# 13                                        AI
# 14    Restructuring after Splunk acquisition
# 15                 Restructuring sales teams
# 16                         Slowing EV demand
# 17     Store closures and cost restructuring
# 18      Cost restructuring with compensation
# 19                   Internal reorganization
# 20         Post-CyberArk acquisition overlap
# 21                                        AI
# 22         Rethinking digital transformation
# 23                                        AI
# 24                                        AI
# 25                     Blast furnace closure
# 26                                        AI
#
# [27 rows x 27 columns]
